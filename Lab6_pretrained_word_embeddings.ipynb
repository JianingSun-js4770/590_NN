# %% [markdown]
# #### Building a model from a pretrained GloVe model
# - Training your own model embedding model is possible however it frequently requires a lot of data
# - What we more frequently do is start with an embedding model trained by Facebook, Google or Stanford and then either:
#     1. Freeze the embedding layer - assuming the linguistic regularity of our corpus/documents matches that off the embeddings generated by the pretrained models
#     2. Use the pretrained weights and update them for our model
#
# - In this class we won't go over fitting skipgram, word2vec or GloVe models from scratch because they require a lot of data and computation resources
# - For a more thorough exposition see the following links:
#     - [Word2Vec](https://radimrehurek.com/gensim/models/word2vec.html)
#     - [Python gensim Word2Vec tutorial with TensorFlow and Keras](http://adventuresinmachinelearning.com/gensim-word2vec-tutorial/)
#     - [A Word2Vec Keras tutorial](http://adventuresinmachinelearning.com/word2vec-keras-tutorial/)
#     - [Code example: Word2Vec (skipgram) in Keras with Gensim](https://github.com/nzw0301/keras-examples/blob/master/Skip-gram-with-NS.ipynb)

# %% [markdown]
# #### What we are going to be doing in this notebook
# - In this notebook we'll go through using pretrained embeddings on our imdb data set
# - When there isn't sufficient data, using some form of pre-trained mode is really beneficial (transfer learning)
#
# - In sequence we will:
#     - Download the raw imdb data set, unzip it, read it and assign pos/neg target values
#     - Tokenize the imdb data set
#     - Download GloVe word embeddings
#     - Prepare the Glove word-embedding matrix
#     - Setup our neural netowrk
#     - Load GloVe embedding in the model
#         - Note we will freeze this layer so that it does not disrupt pre-trained weights
#     - Training the model
#     - Compare the model without pretrained word embeddings

# %% [markdown]
# ### Setting up file imports for IMDB data
# - Here we download the raw individual comments from IMDB users from -`https://www.kaggle.com/iarunava/imdb-movie-reviews-dataset`
# - The file structure is such that you have:
#     - /aclImdb -> (
#         - /test ->
#             - (/neg,/pos, urls_neg.txt, url_post.txt),
#         - /train ->
#             - (/neg,/pos, urls_neg.txt, url_post.txt)))

# %%
# -- Import libraries --
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.datasets import imdb
import numpy as np
import os
# Restrict to 10000 most common words
max_words = 10000

# %%
# LOAD IMDB DATA
(x_train_val, y_train_val), (x_test, y_test) = imdb.load_data(num_words = max_words)
max_val_word_index = max([max(sequence) for sequence in x_train_val])
max_length_review = max([len(sequence) for sequence in x_train_val])

# Printing output
print(" Train and Validation data {x}\n Train labels {y}".format(x = x_train_val.shape, y = y_train_val.shape))
print("_"*20)
print(" Test and Validation  data {x}\n Test labels {y}".format(x = x_test.shape, y = y_test.shape))
print("_"*20)
print("Maximum value of a word index {}".format(max_val_word_index))
print("Maximum length num words of review in train {}".format(max_length_review))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 6s 0us/step
#  Train and Validation data (25000,)
#  Train labels (25000,)
# ____________________
#  Test and Validation  data (25000,)
#  Test labels (25000,)
# ____________________
# Maximum value of a word index 9999
# Maximum length num words of review in train 2494

# %%
# --- Getting reviews ---
# Reverse from integers to words using the DICTIONARY (given by keras...need to do nothing to create it)
# note that words without a mapping are given by a "?"
word_index = imdb.get_word_index()

reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

decoded_review = ' '.join([reverse_word_index.get(i - 3, '?') for i in x_train_val[123]])

print(decoded_review)
# Out:
# ? beautiful and touching movie rich colors great settings good acting and one of the most charming movies i have seen in a while i never saw such an interesting setting when i was in china my wife liked it so much she asked me to ? on and rate it so other would enjoy too

# %%
# -- Parameter setup --
# Cutoff reviews after 100 words
maxlen = 100
# Train on 20000 samples
training_samples = 20000
# Validation on 5000 samples
validation_samples = 5000

# %%
# Padding/bounding number of words in a sequence
data = pad_sequences(x_train_val, maxlen = maxlen) #if the review is less than 100, we complete it with 0s; if greater than 0, we chop it off
labels = np.asarray(y_train_val)
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', labels.shape)
# Out:
# Shape of data tensor: (25000, 100)
# Shape of label tensor: (25000,)

# %%
data
# Out:
# array([[ 762,   21,   14, ...,   61,   86,  733],
#        [  11,    4,  704, ...,   46,    7,  747],
#        [  11,  111, 2936, ...,   35, 1896,  834],
#        ...,
#        [   2,  619,   21, ..., 1479,   18,  567],
#        [ 156,   39,  116, ...,   20, 1123, 3734],
#        [   0,    0,    0, ...,  600,  484,  527]], dtype=int32)

# %%
# -- Shuffling indices --
np.random.seed(1234)
# Shuffling data set  because ordered
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
# --- Training and validation set ---
data = data[indices]
labels = labels[indices]

# - Setting up train/test split -
x_train = data[:training_samples]
y_train = labels[:training_samples]
x_val = data[training_samples:(training_samples + validation_samples)]
y_val = labels[training_samples:(training_samples + validation_samples)]

# %%
labels
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# (1 hour) Download the Glove file, pretrained model, and you can look at the first 10 lines by the `with` chunk of code

# %%
# Downloading the glove file
# WARNING - this is a big file, about 1GB.
import urllib
urllib.request.urlretrieve("http://nlp.stanford.edu/data/glove.6B.zip", '/tmp/glove')
# Out:
# ('/tmp/glove', <http.client.HTTPMessage at 0x7ff478ba55d0>)

# %%
import zipfile
zip_ref = zipfile.ZipFile("/tmp/glove", 'r')
zip_ref.extractall("/tmp/glove.6B")

# %%
with open('/tmp/glove.6B/glove.6B.100d.txt','r') as f:
    for i in range(10):
        print(f.readline()) #every word has an embedding
# Out:
# the -0.038194 -0.24487 0.72812 -0.39961 0.083172 0.043953 -0.39141 0.3344 -0.57545 0.087459 0.28787 -0.06731 0.30906 -0.26384 -0.13231 -0.20757 0.33395 -0.33848 -0.31743 -0.48336 0.1464 -0.37304 0.34577 0.052041 0.44946 -0.46971 0.02628 -0.54155 -0.15518 -0.14107 -0.039722 0.28277 0.14393 0.23464 -0.31021 0.086173 0.20397 0.52624 0.17164 -0.082378 -0.71787 -0.41531 0.20335 -0.12763 0.41367 0.55187 0.57908 -0.33477 -0.36559 -0.54857 -0.062892 0.26584 0.30205 0.99775 -0.80481 -3.0243 0.01254 -0.36942 2.2167 0.72201 -0.24978 0.92136 0.034514 0.46745 1.1079 -0.19358 -0.074575 0.23353 -0.052062 -0.22044 0.057162 -0.15806 -0.30798 -0.41625 0.37972 0.15006 -0.53212 -0.2055 -1.2526 0.071624 0.70565 0.49744 -0.42063 0.26148 -1.538 -0.30223 -0.073438 -0.28312 0.37104 -0.25217 0.016215 -0.017099 -0.38984 0.87424 -0.72569 -0.51058 -0.52028 -0.1459 0.8278 0.27062
#
# , -0.10767 0.11053 0.59812 -0.54361 0.67396 0.10663 0.038867 0.35481 0.06351 -0.094189 0.15786 -0.81665 0.14172 0.21939 0.58505 -0.52158 0.22783 -0.16642 -0.68228 0.3587 0.42568 0.19021 0.91963 0.57555 0.46185 0.42363 -0.095399 -0.42749 -0.16567 -0.056842 -0.29595 0.26037 -0.26606 -0.070404 -0.27662 0.15821 0.69825 0.43081 0.27952 -0.45437 -0.33801 -0.58184 0.22364 -0.5778 -0.26862 -0.20425 0.56394 -0.58524 -0.14365 -0.64218 0.0054697 -0.35248 0.16162 1.1796 -0.47674 -2.7553 -0.1321 -0.047729 1.0655 1.1034 -0.2208 0
 0.22869 -0.51958 -0.79349 -0.20368 -0.50187 0.18748 0.94282 -0.44834 -3.6792 0.044183 -0.26751 2.1997 0.241 -0.033425 0.69553 -0.64472 -0.0072277 0.89575 0.20015 0.46493 0.61933 -0.1066 0.08691 -0.4623 0.18262 -0.15849 0.020791 0.19373 0.063426 -0.31673 -0.48177 -1.3848 0.13669 0.96859 0.049965 -0.2738 -0.035686 -1.0577 -0.24467 0.90366 -0.12442 0.080776 -0.83401 0.57201 0.088945 -0.42532 -0.018253 -0.079995 -0.28581 -0.01089 -0.4923 0.63687 0.23642
#
# " -0.30457 -0.23645 0.17576 -0.72854 -0.28343 -0.2564 0.26587 0.025309 -0.074775 -0.3766 -0.057774 0.12159 0.34384 0.41928 -0.23236 -0.31547 0.60939 0.25117 -0.68667 0.70873 1.2162 -0.1824 -0.48442 -0.33445 0.30343 1.086 0.49992 -0.20198 0.27959 0.68352 -0.33566 -0.12405 0.059656 0.33617 0.37501 0.56552 0.44867 0.11284 -0.16196 -0.94346 -0.67961 0.18581 0.060653 0.43776 0.13834 -0.48207 -0.56141 -0.25422 -0.52445 0.097003 -0.48925 0.19077 0.21481 1.4969 -0.86665 -3.2846 0.56854 0.41971 1.2294 0.78522 -0.29369 0.63803 -1.5926 -0.20437 1.5306 0.13548 0.50722 0.18742 0.48552 -0.28995 0.19573 0.0046515 0.092879 -0.42444 0.64987 0.52839 0.077908 0.8263 -1.2208 -0.34955 0.49855 -0.64155 -0.72308 0.26566 -1.3643 -0.46364 -0.52048 -1.0525 0.22895 -0.3456 -0.658 -0.16735 0.35158 0.74337 0.26074 0.061104 -0.39079 -0.84557 -0.035432 0.17036
#
# 's 0.58854 -0.2025 0.73479 -0.68338 -0.19675 -0.1802 -0.39177 0.34172 -0.60561 0.63816 -0.26695 0.36486 -0.40379 -0.1134 -0.58718 0.2838 0.8025 -0.35303 0.30083 0.078935 0.44416 -0.45906 0.79294 0.50365 0.32805 0.28027 -0.4933 -0.38482 -0.039284 -0.2483 -0.1988 1.1469 0.13228 0.91691 -0.36739 0.89425 0.5426 0.61738 -0.62205 -0.31132 -0.50933 0.23335 1.0826 -0.044637 -0.12767 0.27628 -0.032617 -0.27397 0.77764 -0.50861 0.038307 -0.33679 0.42344 1.2271 -0.53826 -3.2411 0.42626 0.025189 1.3948 0.65085 0.03325 0.37141 0.4044 0.35558 0.98265 -0.61724 0.53901 0.76219 0.30689 0.33065 0.30956 -0.15161 -0.11313 -0.81281 0.6145 -0.44341 -0.19163 -0.089551 -1.5927 0.37405 0.85857 0.54613 -0.31928 0.52598 -1.4802 -0.97931 -0.2939 -0.14724 0.25803 -0.1817 1.0149 0.77649 0.12598 0.54779 -1.0316 0.064599 -0.37523 -0.94475 0.61802 0.39591

# %% [markdown]
# #### Build a vector map
# - We are going to use a 100 dimensional glove embedding
# - Before we do so we need to build a dictionary of words:vector_embeddings
# - Next we build an index that maps words (as strings) to their vector represenation in 100D

# %%
# --- Parsing the GloVe word-embeddings file --
# After unzipping file 

glove_dir = os.path.join('/tmp/', 'glove.6B')

# Dictionary where we store the word:vector_embedding map
embeddings_index = {}
word_index = {}
count=0

# Setting up embedding array
with open(os.path.join(glove_dir, 'glove.6B.100d.txt')) as f:
    for line in f:
        values = line.split()
        word = values[0] #the 1st element is the word (key)
        coefs = np.asarray(values[1:], dtype='float32') #the remaining elements are array that casted as "float" type
        # Embeddings is a dictionary of words:word_vector_embeddings
        embeddings_index[word] = coefs
        word_index[word] = count
        count+=1

print('Found {} word vectors.'.format(len(embeddings_index)))
# Out:
# Found 400000 word vectors.

# %%
# What is the embedding of the word 'happy'
embeddings_index['happy']
# Out:
# array([-0.090436 ,  0.19636  ,  0.29474  , -0.47706  , -0.80436  ,
#         0.3078   , -0.55205  ,  0.58453  , -0.17056  , -0.84846  ,
#         0.19528  ,  0.23671  ,  0.46827  , -0.58977  , -0.12163  ,
#        -0.24697  , -0.072944 ,  0.17259  , -0.0485   ,  0.9527   ,
#         0.50629  ,  0.58497  , -0.19367  , -0.45459  , -0.031095 ,
#         0.51633  , -0.24052  , -0.1007   ,  0.53627  ,  0.024225 ,
#        -0.50162  ,  0.73692  ,  0.49468  , -0.34744  ,  0.89337  ,
#         0.057439 , -0.19127  ,  0.39333  ,  0.21182  , -0.89837  ,
#         0.078704 , -0.16344  ,  0.45261  , -0.41096  , -0.19499  ,
#        -0.13489  , -0.016313 , -0.021849 ,  0.17136  , -1.2413   ,
#         0.079503 , -0.91144  ,  0.35699  ,  0.36289  , -0.24934  ,
#        -2.1196   ,  0.14534  ,  0.52964  ,  0.90134  ,  0.033603 ,
#         0.022809 ,  0.70625  , -1.0362   , -0.59809  ,  0.70592  ,
#        -0.072793 ,  0.67033  ,  0.52763  , -0.47807  , -0.67374  ,
#         0.36632  , -0.38284  , -0.10349  , -0.6402   ,  0.18104  ,
#         0.82568  ,  0.066403 , -0.40791  , -0.083813 , -0.36487  ,
#         0.045362 , -0.073527 , -0.20117  ,  0.37441  , -1.4024   ,
#        -0.25605  , -0.4708   , -0.16145  , -0.87921  , -0.36325  ,
#        -0.17357  , -0.077983 ,  0.43273  ,  0.0089295, -1.0316   ,
#        -0.11589  , -0.34524  ,  0.11514  , -0.40812  ,  0.20203  ],
#       dtype=float32)

# %% [markdown]
# - Here we setup the embedding matrix with only the words that we need
# - Note that we loop over the file only selecting the most frequently occuring words

# %%
print('Our word index dictionary is given by: (word, index), a sample 10 entries are:')
list(word_index.items())[:10]
# Out:
# Our word index dictionary is given by: (word, index), a sample 10 entries are:
# [('the', 0),
#  (',', 1),
#  ('.', 2),
#  ('of', 3),
#  ('to', 4),
#  ('and', 5),
#  ('in', 6),
#  ('a', 7),
#  ('"', 8),
#  ("'s", 9)]

# %%
# --- Preprocessing the GloVe word-embeddings matrix --
embedding_dim = 100

# Instantiating a 10000 x 100 matrix 
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    # Make sure that we are not exceeding the max token size
    if i < max_words:
        # Get the embedded vector for the word
        embedding_vector = embeddings_index.get(word)
        # Provided that a word is known store it in the 
        # embeddig matrix at position i
        if embedding_vector is not None:
            embedding_matrix[i, :] = embedding_vector

# %%
print("The size of the word embedding matrix is:" + str(embedding_matrix.shape))
# Out:
# The size of the word embedding matrix is:(10000, 100)

# %%
# --- Definining our model ---
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense

# -- Using the GloVe Embedding to train our model ---
model = Sequential()
model.add(Embedding(max_words, embedding_dim, input_length = maxlen)) #100 dim for 100 wrds each
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1,activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 100)          1000000
# _________________________________________________________________
# flatten (Flatten)            (None, 10000)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                320032
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,320,065
# Trainable params: 1,320,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Note that we already have over 1 million parameters in this network. Most of those are contained in the embedding layer.
#
# But those embeddings weights aren't free parameters. Instead, we'll use the pre-trained Glove embedding and insert them into the model, and then freeze those weights so that they won't be touched during gradient descent.

# %% [markdown]
# - Since we are interested in using our pretrain model we need to :
#     1. Load the weights into the first layer
#     2. Freeze that layer to make sure that during training it does not get updated
# - Here we load the pretrained weights into the first layer (embedding layer) and then freeze the layer

# %%
# Setting up the weights
model.layers[0].set_weights([embedding_matrix])

# Freeze or train the GloVe layer
model.layers[0].trainable = False

# %%
model.summary()
#Non-trainable params is frozen embedding weights that we used the pretrained model Glove
#we only need to train 320,065 trainable params for dense layers
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 100)          1000000
# _________________________________________________________________
# flatten (Flatten)            (None, 10000)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                320032
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,320,065
# Trainable params: 320,065
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %% [markdown]
# Note the big decrease in the number of trainable parameters.

# %%
# -- Training our model --
model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics=['acc'])
history = model.fit(x_train,y_train,
                   epochs =50,
                   batch_size = 256,
                   validation_data = (x_val, y_val))             
#val_accuracy is a little bit over 50-50 guess
# Out:
# Epoch 1/50
# 79/79 [==============================] - 1s 8ms/step - loss: 0.8555 - acc: 0.5063 - val_loss: 0.7376 - val_acc: 0.4920
# Epoch 2/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6955 - acc: 0.5547 - val_loss: 0.6921 - val_acc: 0.5240
# Epoch 3/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6817 - acc: 0.5868 - val_loss: 0.6696 - val_acc: 0.5870
# Epoch 4/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6519 - acc: 0.6100 - val_loss: 0.6778 - val_acc: 0.5726
# Epoch 5/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6579 - acc: 0.6151 - val_loss: 0.6905 - val_acc: 0.5652
# Epoch 6/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6315 - acc: 0.6417 - val_loss: 0.7771 - val_acc: 0.5184
# Epoch 7/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6172 - acc: 0.6586 - val_loss: 0.6788 - val_acc: 0.5856
# Epoch 8/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5975 - acc: 0.6759 - val_loss: 0.8095 - val_acc: 0.5326
# Epoch 9/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6028 - acc: 0.6684 - val_loss: 0.6703 - val_acc: 0.5914
# Epoch 10/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5814 - acc: 0.6913 - val_loss: 0.6844 - val_acc: 0.5950
# Epoch 11/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5686 - acc: 0.6999 - val_loss: 0.7052 - val_acc: 0.5776
# Epoch 12/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5537 - acc: 0.7066 - val_loss: 0.6812 - val_acc: 0.5768
# Epoch 13/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5431 - acc: 0.7158 - val_loss: 0.7811 - val_acc: 0.5656
# Epoch 14/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5342 - acc: 0.7293 - val_loss: 0.8478 - val_acc: 0.5612
# Epoch 15/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5211 - acc: 0.7338 - val_loss: 0.7041 - val_acc: 0.5882
# Epoch 16/50
# 79/79 [==============================] - 1s 6ms/step - loss: 0.5060 - acc: 0.7436 - val_loss: 0.6811 - val_acc: 0.5728
# Epoch 17/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4889 - acc: 0.7552 - val_loss: 0.7489 - val_acc: 0.5930
# Epoch 18/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4906 - acc: 0.7489 - val_loss: 0.7302 - val_acc: 0.5914
# Epoch 19/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4644 - acc: 0.7677 - val_loss: 0.8204 - val_acc: 0.5884
# Epoch 20/50
# 79/79 [==============================] - 1s 6ms/step - loss: 0.4586 - acc: 0.7673 - val_loss: 0.8644 - val_acc: 0.5690
# Epoch 21/50
# 79/79 [==============================] - 1s 6ms/step - loss: 0.4428 - acc: 0.7828 - val_loss: 0.7608 - val_acc: 0.5894
# Epoch 22/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4211 - acc: 0.7954 - val_loss: 0.7630 - val_acc: 0.5894
# Epoch 23/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4160 - acc: 0.7995 - val_loss: 0.7026 - val_acc: 0.5836
# Epoch 24/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3988 - acc: 0.8092 - val_loss: 1.3961 - val_acc: 0.5298
# Epoch 25/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3938 - acc: 0.8096 - val_loss: 0.8432 - val_acc: 0.5826
# Epoch 26/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3719 - acc: 0.8217 - val_loss: 0.8043 - val_acc: 0.5856
# Epoch 27/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3627 - acc: 0.8250 - val_loss: 0.9311 - val_acc: 0.5786
# Epoch 28/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3448 - acc: 0.8328 - val_loss: 0.8429 - val_acc: 0.5704
# Epoch 29/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3341 - acc: 0.8440 - val_loss: 0.9345 - val_acc: 0.5880
# Epoch 30/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3211 - acc: 0.8479 - val_loss: 1.2246 - val_acc: 0.5496
# Epoch 31/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3071 - acc: 0.8555 - val_loss: 0.8908 - val_acc: 0.5764
# Epoch 32/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3041 - acc: 0.8529 - val_loss: 0.9219 - val_acc: 0.5780
# Epoch 33/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2834 - acc: 0.8704 - val_loss: 1.1495 - val_acc: 0.5742
# Epoch 34/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2805 - acc: 0.8711 - val_loss: 1.0962 - val_acc: 0.5782
# Epoch 35/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2629 - acc: 0.8788 - val_loss: 1.1612 - val_acc: 0.5826
# Epoch 36/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2550 - acc: 0.8798 - val_loss: 1.1228 - val_acc: 0.5760
# Epoch 37/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2521 - acc: 0.8855 - val_loss: 1.2299 - val_acc: 0.5750
# Epoch 38/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2335 - acc: 0.8910 - val_loss: 1.3767 - val_acc: 0.5568
# Epoch 39/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2286 - acc: 0.8961 - val_loss: 1.1615 - val_acc: 0.5782
# Epoch 40/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2188 - acc: 0.8992 - val_loss: 1.2587 - val_acc: 0.5744
# Epoch 41/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2152 - acc: 0.9066 - val_loss: 0.9725 - val_acc: 0.5724
# Epoch 42/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2030 - acc: 0.9155 - val_loss: 1.1104 - val_acc: 0.5856
# Epoch 43/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1980 - acc: 0.9169 - val_loss: 1.2356 - val_acc: 0.5770
# Epoch 44/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1845 - acc: 0.9194 - val_loss: 1.3707 - val_acc: 0.5812
# Epoch 45/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1815 - acc: 0.9287 - val_loss: 1.5416 - val_acc: 0.5742
# Epoch 46/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1984 - acc: 0.9189 - val_loss: 1.0758 - val_acc: 0.5654
# Epoch 47/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1630 - acc: 0.9306 - val_loss: 1.3659 - val_acc: 0.5838
# Epoch 48/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1893 - acc: 0.9250 - val_loss: 1.2870 - val_acc: 0.5774
# Epoch 49/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1466 - acc: 0.9394 - val_loss: 1.6259 - val_acc: 0.5674
# Epoch 50/50
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1556 - acc: 0.9341 - val_loss: 1.6450 - val_acc: 0.5726

# %%
#-- Plotting the results --
import matplotlib.pyplot as plt

# ~ Plotting parameters ~
# Pulling out :
#   - Training: accuracy and loss
#   - validation: accuracy and loss
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# Plotting the data 

# Training + Valdiation Accuracy
epochs = range(1,len(acc) + 1)
plt.plot( epochs, acc, 'bo', label = 'Training Accuracy')
plt.plot( epochs, val_acc, 'b', label = 'Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

# Training + Validation Loss
plt.plot( epochs, loss, 'bo', label = 'Training Loss')
plt.plot( epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# What do you think of these loss curves? What might we changes in the model?
#
# **Exercise**: Change the model using some techniques we've learned about in this class and refit.
